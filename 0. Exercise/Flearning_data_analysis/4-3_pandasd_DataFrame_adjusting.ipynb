# %%
import pandas as pd
import numpy  as np

# %%
df = pd.DataFrame(np.random.randn(6,4))
df
# Out:
#           0         1         2         3
# 0 -0.856468 -0.140437 -0.434089  0.511784
# 1 -1.153482  1.182993  0.287602 -0.909489
# 2  0.154677  1.922756 -0.833920  0.543103
# 3 -1.334704  1.045100 -0.528614 -0.594403
# 4 -1.200802  1.455034 -1.606139  0.494229
# 5  1.025506 -1.598185 -0.441665  0.024009

# %%
df.columns = ("A", "B", "C", "D")
df.index   = pd.date_range("20160701", periods=6)

# %%
df.index
# Out:
# DatetimeIndex(['2016-07-01', '2016-07-02', '2016-07-03', '2016-07-04',
#                '2016-07-05', '2016-07-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    A         B         C         D
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009

# %%
df["F"] = [1.0, np.nan, 3.5, 6.1, np.nan, 7.0]
df
# Out:
#                    A         B         C         D    F
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784  1.0
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489  NaN
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403  6.1
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229  NaN
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df.dropna(how="any")
# Out:
#                    A         B         C         D    F
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784  1.0
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403  6.1
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df.dropna(how="all")
# Out:
#                    A         B         C         D    F
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784  1.0
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489  NaN
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403  6.1
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229  NaN
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df.fillna(value=5.0)
# Out:
#                    A         B         C         D    F
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784  1.0
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489  5.0
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403  6.1
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229  5.0
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df
# Out:
#                    A         B         C         D    F
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784  1.0
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489  NaN
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403  6.1
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229  NaN
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df.isnull()
# Out:
#                 A      B      C      D      F
# 2016-07-01  False  False  False  False  False
# 2016-07-02  False  False  False  False   True
# 2016-07-03  False  False  False  False  False
# 2016-07-04  False  False  False  False  False
# 2016-07-05  False  False  False  False   True
# 2016-07-06  False  False  False  False  False

# %%
df.loc[df.isnull()["F"],:]
# Out:
#                    A         B         C         D   F
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489 NaN
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229 NaN

# %%
pd.to_datetime("20160701")
# Out:
# Timestamp('2016-07-01 00:00:00')

# %%
df.drop(pd.to_datetime("20160701"))
# Out:
#                    A         B         C         D    F
# 2016-07-02 -1.153482  1.182993  0.287602 -0.909489  NaN
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-04 -1.334704  1.045100 -0.528614 -0.594403  6.1
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229  NaN
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df.drop([pd.to_datetime("20160702"), pd.to_datetime("20160704")])
# Out:
#                    A         B         C         D    F
# 2016-07-01 -0.856468 -0.140437 -0.434089  0.511784  1.0
# 2016-07-03  0.154677  1.922756 -0.833920  0.543103  3.5
# 2016-07-05 -1.200802  1.455034 -1.606139  0.494229  NaN
# 2016-07-06  1.025506 -1.598185 -0.441665  0.024009  7.0

# %%
df.drop(["B", "D"], axis=1)
# Out:
#                    A         C    F
# 2016-07-01 -0.856468 -0.434089  1.0
# 2016-07-02 -1.153482  0.287602  NaN
# 2016-07-03  0.154677 -0.833920  3.5
# 2016-07-04 -1.334704 -0.528614  6.1
# 2016-07-05 -1.200802 -1.606139  NaN
# 2016-07-06  1.025506 -0.441665  7.0
